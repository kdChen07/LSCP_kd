# %% [markdown]
# <a href="https://colab.research.google.com/github/kdChen07/progress-and-problems/blob/main/LSCP_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas
# !pip install pulp

# %%
import numpy
import geopandas 
import pandas
import pulp
from shapely.geometry import Point
import matplotlib.pyplot as plt
from google.colab import files

# %% [markdown]
# 导入本地库SPOPT

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/spopt-gsoc21-facloc
# Out:
# /content/drive/MyDrive/Colab Notebooks/spopt-gsoc21-facloc

# %%
# !python setup.py install

# %% [markdown]
# 导入数据380个MSOA与2736个潜在POI之间的距离distance、380个MSOA、2736个潜在POI选址和全部MSOA的边界

# %%
network_distance = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/data/distance8816.csv')
demand_points = pandas.read_csv("MSOA380.csv", index_col=0)
facility_points = pandas.read_csv('/content/drive/MyDrive/Colab Notebooks/data/opt_points2700.csv', index_col=0)

# %%
tract = geopandas.read_file('https://github.com/LingruFeng/dissertation/blob/main/data_github/England_basemap/MSOA_Boundary_with_population.gpkg?raw=true')
tract = tract.to_crs('epsg:4326')

# %%
display(network_distance)
# Out:
#       index  Distance in meter  origin_id  destination_id
# 0         1            15669.6  E02002527            4155
# 1         2              608.3  E02002527            4159
# 2         3            11904.9  E02002527            4609
# 3         4            14355.9  E02002527            5050
# 4         5              989.8  E02002527            5056
# ...     ...                ...        ...             ...
# 8811   8812             6549.4  E02006880           17608
# 8812   8813             4303.6  E02006880           18563
# 8813   8814             1405.0  E02006880           18686
# 8814   8815             6235.8  E02006880           19549
# 8815   8816             7014.5  E02006880           19886
#
# [8816 rows x 4 columns]

# %%
display(demand_points)
# Out:
#        objectid   msoa11cd  point_lon  point_lat
# index
# 1           311  E02002527  -0.895104  54.556813
# 2          1636  E02002692  -0.900405  53.979796
# 3          1634  E02002693  -0.271017  53.945190
# 4          1632  E02002694  -0.778200  53.931540
# 5          1631  E02002695  -0.168981  53.909875
# ...         ...        ...        ...        ...
# 376        6413  E02006845  -2.906422  51.358374
# 377        6410  E02006846  -2.929576  51.347977
# 378        5000  E02006857   0.313122  50.786367
# 379        1484  E02006870  -0.786744  54.132341
# 380        5705  E02006880   1.167870  51.078965
#
# [380 rows x 4 columns]

# %%
display(facility_points)
# Out:
#                                        name  point_lon  point_lat
# index
# 22     Seaton & District Community Hospital  -3.071506  50.711803
# 24         Radcliffe Day and Night Pharmacy  -1.039834  52.947186
# 28                            Leek Pharmacy  -2.007594  53.114610
# 31                 Rosebird Centre Pharmacy  -1.698512  52.179296
# 37             Anglia Community Eye Service   0.141951  52.648342
# ...                                     ...        ...        ...
# 21777             Crown Chiropractic Clinic   0.551217  51.877829
# 21783        Highworth Physiotherapy Clinic  -1.710237  51.630451
# 21789                       Chepstow Clinic  -2.673831  51.642387
# 21801           Derbyshire Healthcare Trust  -1.553070  53.138007
# 21802                Amesbury Health Centre  -1.778055  51.172152
#
# [2738 rows x 3 columns]

# %%
tract.plot()

# %% [markdown]
# 形成表格

# %%
ntw_dist_piv = network_distance.pivot_table(values="Distance in meter", index="destination_id", columns="origin_id")
ntw_dist_piv
# Out:
# origin_id       E02002527  E02002692  ...  E02006870  E02006880
# destination_id                        ...
# 22                    NaN        NaN  ...        NaN        NaN
# 24                    NaN        NaN  ...        NaN        NaN
# 28                    NaN        NaN  ...        NaN        NaN
# 31                    NaN        NaN  ...        NaN        NaN
# 37                    NaN        NaN  ...        NaN        NaN
# ...                   ...        ...  ...        ...        ...
# 21777                 NaN        NaN  ...        NaN        NaN
# 21783                 NaN        NaN  ...        NaN        NaN
# 21789                 NaN        NaN  ...        NaN        NaN
# 21801                 NaN        NaN  ...        NaN        NaN
# 21802                 NaN        NaN  ...        NaN        NaN
#
# [2738 rows x 380 columns]

# %% [markdown]
# 形成矩阵

# %%
cost_matrix = ntw_dist_piv.to_numpy()
cost_matrix
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %% [markdown]
# 由于存在空值nan，空值为MSOA与POI之间无法提供疫苗服务，而能够提供服务的距离10英里为16093.44公里，因此，将空值填补为20000公里。

# %%
cost_matrix[numpy.isnan(cost_matrix)] = 20000

# %%
cost_matrix
# Out:
# array([[20000., 20000., 20000., ..., 20000., 20000., 20000.],
#        [20000., 20000., 20000., ..., 20000., 20000., 20000.],
#        [20000., 20000., 20000., ..., 20000., 20000., 20000.],
#        ...,
#        [20000., 20000., 20000., ..., 20000., 20000., 20000.],
#        [20000., 20000., 20000., ..., 20000., 20000., 20000.],
#        [20000., 20000., 20000., ..., 20000., 20000., 20000.]])

# %%
facility_points_gdf = geopandas.GeoDataFrame(
    facility_points,
    geometry=geopandas.points_from_xy(
        facility_points.point_lon, facility_points.point_lat
    ),
).sort_values(by=['index']).reset_index()

demand_points_gdf = geopandas.GeoDataFrame(
    demand_points,
    geometry=geopandas.points_from_xy(demand_points.point_lon, demand_points.point_lat),
).sort_values(by=['msoa11cd']).reset_index()

# %%
facility_points_gdf
# Out:
#       index  ...                   geometry
# 0        22  ...  POINT (-3.07151 50.71180)
# 1        24  ...  POINT (-1.03983 52.94719)
# 2        28  ...  POINT (-2.00759 53.11461)
# 3        31  ...  POINT (-1.69851 52.17930)
# 4        37  ...   POINT (0.14195 52.64834)
# ...     ...  ...                        ...
# 2733  21777  ...   POINT (0.55122 51.87783)
# 2734  21783  ...  POINT (-1.71024 51.63045)
# 2735  21789  ...  POINT (-2.67383 51.64239)
# 2736  21801  ...  POINT (-1.55307 53.13801)
# 2737  21802  ...  POINT (-1.77806 51.17215)
#
# [2738 rows x 5 columns]

# %%
demand_points_gdf
# Out:
#      index  objectid  ...  point_lat                   geometry
# 0        1       311  ...  54.556813  POINT (-0.89510 54.55681)
# 1        2      1636  ...  53.979796  POINT (-0.90041 53.97980)
# 2        3      1634  ...  53.945190  POINT (-0.27102 53.94519)
# 3        4      1632  ...  53.931540  POINT (-0.77820 53.93154)
# 4        5      1631  ...  53.909875  POINT (-0.16898 53.90988)
# ..     ...       ...  ...        ...                        ...
# 375    376      6413  ...  51.358374  POINT (-2.90642 51.35837)
# 376    377      6410  ...  51.347977  POINT (-2.92958 51.34798)
# 377    378      5000  ...  50.786367   POINT (0.31312 50.78637)
# 378    379      1484  ...  54.132341  POINT (-0.78674 54.13234)
# 379    380      5705  ...  51.078965   POINT (1.16787 51.07897)
#
# [380 rows x 6 columns]

# %%
service_dist = 16093.44

# %% [markdown]
# 定义plot_results函数

# %%
from matplotlib.patches import Patch
import matplotlib.lines as mlines

dv_colors = [
    "darkcyan",
    "mediumseagreen",
    "cyan",
    "darkslategray",
    "lightskyblue",
    "limegreen",
    "darkgoldenrod",
    "peachpuff",
    "coral",
    "mediumvioletred",
    "blueviolet",
    "fuchsia",
    "thistle",
    "lavender",
    "saddlebrown",
] 

def plot_results(model, facility_points_gdf, demand_points_gdf, facility_count, title):
    arr_points = []
    fac_sites = []
    
    for i in range(facility_count):
        if model.fac2cli[i]:

            geom = demand_points_gdf.iloc[model.fac2cli[i]]['geometry']
            arr_points.append(geom)
            fac_sites.append(i)

    fig, ax = plt.subplots(figsize=(36,36))
    legend_elements = []

    tract.plot(ax=ax, alpha=1, color='tan', zorder=1)
    legend_elements.append(mlines.Line2D(
        [],
        [],
        color='tan',
        label='tract',
    ))

    facility_points_gdf.plot(ax=ax, color='brown', marker="*", markersize=80, zorder=2)
    legend_elements.append(mlines.Line2D(
        [],
        [],
        color='brown',
        marker="*",
        linewidth=0,
        label=f'facility sites ($n$={facility_count})'
    ))

    demand_points_gdf.plot(ax=ax, edgecolor='k', color='white', zorder=2)
    legend_elements.append(mlines.Line2D(
        [],
        [],
        color='white',
        marker="o",
        markeredgecolor='k',
        linewidth=0,
        label=f'clients not covered'
    ))
 
    for i in range(len(arr_points)):
        gdf = geopandas.GeoDataFrame(arr_points[i])

        label = f"points covered by {facility_points_gdf.iloc[[fac_sites[i]]]['NAME'].squeeze()}"
        legend_elements.append(Patch(facecolor=dv_colors[i], edgecolor="k", label=label))

        gdf.plot(ax=ax, zorder=3, alpha=0.7, edgecolor="k", color=dv_colors[i], label=label)
        facility_points_gdf.iloc[[fac_sites[i]]].plot(ax=ax,
                                marker="*",
                                markersize=200 * 3.0,
                                alpha=0.8,
                                zorder=4,
                                edgecolor="k",
                                facecolor=dv_colors[i])
        
        legend_elements.append(mlines.Line2D(
            [],
            [],
            color=dv_colors[i],
            marker="*",
            ms=20 / 2,
            markeredgecolor="k",
            linewidth=0,
            alpha=0.8,
            label=f"{facility_points_gdf.iloc[[fac_sites[i]]]['NAME'].squeeze()}",
        ))

    plt.title(title, fontweight="bold")
    plt.legend(handles = legend_elements, loc='upper left', bbox_to_anchor=(1.05, 1))

# %% [markdown]
# 调用LSCP函数，并运行

# %%
from spopt.locate.coverage import LSCP

# %%
# !sudo apt-get install python-glpk
# !sudo apt-get install glpk-utils

# %%
lscp = LSCP.from_cost_matrix(cost_matrix, service_dist)
lscp = lscp.solve(pulp.GLPK_CMD(msg=False))

lscp.facility_client_array()
plot_results(lscp, facility_points_gdf, demand_points_gdf, facility_points_gdf.shape[0], "LSCP")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1468         try:
# -> 1469             return self.obj._take_with_is_copy(key, axis=axis)
#    1470         except IndexError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3362         """
# -> 3363         result = self.take(indices=indices, axis=axis)
#    3364         # Maybe set copy if we didn't actually change the index.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3350         new_data = self._mgr.take(
# -> 3351             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3352         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1448         if convert:
# -> 1449             indexer = maybe_convert_indices(indexer, n)
#    1450
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexers.py in maybe_convert_indices(indices, n)
#     249     if mask.any():
# --> 250         raise IndexError("indices are out-of-bounds")
#     251     return indices
#
# IndexError: indices are out-of-bounds
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-01305d7b2051> in <module>()
#       3
#       4 lscp.facility_client_array()
# ----> 5 plot_results(lscp, facility_points_gdf, demand_points_gdf, facility_points_gdf.shape[0], "LSCP")
#
# <ipython-input-16-92c8b8299d29> in plot_results(model, facility_points_gdf, demand_points_gdf, facility_count, title)
#      27         if model.fac2cli[i]:
#      28
# ---> 29             geom = demand_points_gdf.iloc[model.fac2cli[i]]['geometry']
#      30             arr_points.append(geom)
#      31             fac_sites.append(i)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1485         # a list of integers
#    1486         elif is_list_like_indexer(key):
# -> 1487             return self._get_list_axis(key, axis=axis)
#    1488
#    1489         # a single integer
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_list_axis(self, key, axis)
#    1470         except IndexError as err:
#    1471             # re-raise with different error message
# -> 1472             raise IndexError("positional indexers are out-of-bounds") from err
#    1473
#    1474     def _getitem_axis(self, key, axis: int):
#
# IndexError: positional indexers are out-of-bounds

# %%
facility_points_gdf.plot(color='brown', marker="*", markersize=40, zorder=1,figsize=(18,18))

# %%
demand_points_gdf.plot(color='blue', marker="*", markersize=50, zorder=2,figsize=(18,18))

# %%
tract.plot(color='tan',alpha=1, zorder=1,figsize=(18,18))
