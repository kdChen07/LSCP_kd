# %% [markdown]
# <a href="https://colab.research.google.com/github/kdChen07/progress-and-problems/blob/main/distance18993.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install access
# !pip install logging
# !pip install geopandas
# Out:
# Collecting access
#   Downloading access-1.1.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: pandas>=0.23.4 in /usr/local/lib/python3.7/dist-packages (from access) (1.1.5)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.7/dist-packages (from access) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->access) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.4->access) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.4->access) (1.15.0)
# Installing collected packages: access
# Successfully installed access-1.1.3
# Collecting logging
#   Downloading logging-0.4.9.6.tar.gz (96 kB)
#      |████████████████████████████████| 96 kB 4.1 MB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/93/4b/979db9e44be09f71e85c9c8cfc42f258adfb7d93ce01deed2788b2948919/logging-0.4.9.6.tar.gz#sha256=26f6b50773f085042d301085bd1bf5d9f3735704db9f37c1ce6d8b85c38f2417 (from https://pypi.org/simple/logging/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement logging (from versions: 0.4.9.6)
# ERROR: No matching distribution found for logging
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 28.2 MB/s
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp37-cp37m-manylinux1_x86_64.whl (15.4 MB)
#      |████████████████████████████████| 15.4 MB 37 kB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.1.0-cp37-cp37m-manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 53.3 MB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.1.5)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.7.1)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2021.5.30)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.9.0 munch-2.5.0 pyproj-3.1.0

# %%
from access import Access, weights, datasets
import logging
import pandas as pd
import geopandas as gpd
from shapely import wkt
import requests
import json
from google.colab import files

# %%
MSOA=pd.read_csv('点MSOAs Lack of Vaccination Service.csv')
MSOA.head(1)
# Out:
#    index  objectid  ...   MSOA MSOA_with_supply
# 0      1       311  ...  False            False
#
# [1 rows x 6 columns]

# %%
MSOA['geometry'] = MSOA['geometry'].apply(wkt.loads)
MSOA_lack = gpd.GeoDataFrame(MSOA, geometry='geometry')
MSOA_lack.crs = 'epsg:27700'

# %%
MSOA_lack
# Out:
#      index  objectid  ...   MSOA MSOA_with_supply
# 0        1       311  ...  False            False
# 1        2      1636  ...  False            False
# 2        3      1634  ...  False            False
# 3        4      1632  ...  False            False
# 4        5      1631  ...  False            False
# ..     ...       ...  ...    ...              ...
# 378    379      6413  ...  False            False
# 379    380      6410  ...  False            False
# 380    381      5000  ...  False            False
# 381    382      1484  ...  False            False
# 382    383      5705  ...  False            False
#
# [383 rows x 6 columns]

# %%
MSOA_lack = MSOA_lack.to_crs('epsg:4326')
MSOA_lack
# Out:
#      index  objectid  ...   MSOA MSOA_with_supply
# 0        1       311  ...  False            False
# 1        2      1636  ...  False            False
# 2        3      1634  ...  False            False
# 3        4      1632  ...  False            False
# 4        5      1631  ...  False            False
# ..     ...       ...  ...    ...              ...
# 378    379      6413  ...  False            False
# 379    380      6410  ...  False            False
# 380    381      5000  ...  False            False
# 381    382      1484  ...  False            False
# 382    383      5705  ...  False            False
#
# [383 rows x 6 columns]

# %%
MSOA_lack['MSOA_lon'] = MSOA_lack['geometry'].x
MSOA_lack['MSOA_lat'] = MSOA_lack['geometry'].y
MSOA_lack['demand_df'] = 1

# %%
MSOA_lack
# Out:
#      index  objectid   msoa11cd  ...  MSOA_lon   MSOA_lat  demand_df
# 0        1       311  E02002527  ... -0.895104  54.556813          1
# 1        2      1636  E02002692  ... -0.900405  53.979796          1
# 2        3      1634  E02002693  ... -0.271017  53.945190          1
# 3        4      1632  E02002694  ... -0.778200  53.931540          1
# 4        5      1631  E02002695  ... -0.168981  53.909875          1
# ..     ...       ...        ...  ...       ...        ...        ...
# 378    379      6413  E02006845  ... -2.906422  51.358374          1
# 379    380      6410  E02006846  ... -2.929576  51.347977          1
# 380    381      5000  E02006857  ...  0.313122  50.786367          1
# 381    382      1484  E02006870  ... -0.786744  54.132341          1
# 382    383      5705  E02006880  ...  1.167870  51.078965          1
#
# [383 rows x 9 columns]

# %%
MSOA_lack_df = MSOA_lack[['msoa11cd','MSOA_lon','MSOA_lat']]
MSOA_lack_df
# Out:
#       msoa11cd  MSOA_lon   MSOA_lat
# 0    E02002527 -0.895104  54.556813
# 1    E02002692 -0.900405  53.979796
# 2    E02002693 -0.271017  53.945190
# 3    E02002694 -0.778200  53.931540
# 4    E02002695 -0.168981  53.909875
# ..         ...       ...        ...
# 378  E02006845 -2.906422  51.358374
# 379  E02006846 -2.929576  51.347977
# 380  E02006857  0.313122  50.786367
# 381  E02006870 -0.786744  54.132341
# 382  E02006880  1.167870  51.078965
#
# [383 rows x 3 columns]

# %%
df=pd.read_csv('poi_three_types1.csv')
df.head(1)
# Out:
#    index          name  feature_easting  feature_northing  pointx_class
# 0      1  Reiver House         338714.0          556014.0       5280365

# %%
point = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.feature_easting, df.feature_northing))
point.crs = 'epsg:27700'

# %%
point
# Out:
#        index  ...                       geometry
# 0          1  ...  POINT (338714.000 556014.000)
# 1          2  ...  POINT (430296.000 279574.000)
# 2          3  ...  POINT (527876.000 168073.000)
# 3          4  ...  POINT (410903.000 421112.000)
# 4          5  ...  POINT (381373.000 410753.000)
# ...      ...  ...                            ...
# 21807  21808  ...  POINT (318232.000 176550.000)
# 21808  21809  ...  POINT (444081.000 111092.000)
# 21809  21810  ...  POINT (415348.000 280208.000)
# 21810  21811  ...  POINT (533193.000 181452.000)
# 21811  21812  ...  POINT (429836.000 433768.000)
#
# [21812 rows x 6 columns]

# %%
point = point.to_crs('epsg:4326')
point['point_lon'] = point['geometry'].x
point['point_lat'] = point['geometry'].y

# %%
point['supply_value']=1

# %%
point
# Out:
#        index                      name  ...  point_lat  supply_value
# 0          1              Reiver House  ...  54.895084             1
# 1          2           Lloyds Pharmacy  ...  52.413332             1
# 2          3           Wilson Hospital  ...  51.397288             1
# 3          4           Elland Pharmacy  ...  53.686351             1
# 4          5          Pimhole Pharmacy  ...  53.593018             1
# ...      ...                       ...  ...        ...           ...
# 21807  21808                 Ultralase  ...  51.481971             1
# 21808  21809     Fadeaway Laser Clinic  ...  50.897631             1
# 21809  21810               Midland Eye  ...  52.419652             1
# 21810  21811  Optimax Laser Eye Clinic  ...  51.516296             1
# 21811  21812  Optimax Laser Eye Clinic  ...  53.799366             1
#
# [21812 rows x 9 columns]

# %%
point_df = point[['index','point_lon','point_lat']]
point_df
# Out:
#        index  point_lon  point_lat
# 0          1  -2.957088  54.895084
# 1          2  -1.556017  52.413332
# 2          3  -0.163246  51.397288
# 3          4  -1.836388  53.686351
# 4          5  -2.282894  53.593018
# ...      ...        ...        ...
# 21807  21808  -3.178908  51.481971
# 21808  21809  -1.374558  50.897631
# 21809  21810  -1.775749  52.419652
# 21810  21811  -0.081829  51.516296
# 21811  21812  -1.548501  53.799366
#
# [21812 rows x 3 columns]

# %%
distance = Access(demand_df = MSOA_lack,
           demand_index='msoa11cd',
           demand_value='demand_df',
           supply_df= point,
           supply_index= 'index',
           supply_value=['supply_value']
                 )

distance.demand_df = distance.demand_df.to_crs('epsg:27700')
distance.supply_df = distance.supply_df.to_crs('epsg:27700')

# %%
distance.create_euclidean_distance(threshold = 16093.44)
distance.cost_df
# Out:
#           euclidean     origin   dest
# 0      13167.873206  E02002527    124
# 1      12162.918741  E02002527   4155
# 2        414.405629  E02002527   4159
# 3      12726.938554  E02002527   4162
# 4       8900.118874  E02002527   4609
# ...             ...        ...    ...
# 18989   3422.794868  E02006880  18563
# 18990    868.464919  E02006880  18686
# 18991  15418.968215  E02006880  18900
# 18992   3953.783726  E02006880  19549
# 18993   6479.347506  E02006880  19886
#
# [18994 rows x 3 columns]

# %%
distance.cost_df.to_csv('123.csv')
files.download('123.csv')

# %%
euclidean_distance_matrix = distance.cost_df

# %%
euclidean_distance_matrix = pd.merge(left = euclidean_distance_matrix, 
                                     right = point_df, 
                                     how = 'left', 
                                     left_on = 'dest', 
                                     right_on = 'index')
euclidean_distance_matrix = pd.merge(left = euclidean_distance_matrix, 
                                     right = MSOA_lack_df, 
                                     how = 'left', 
                                     left_on = 'origin', 
                                     right_on = 'msoa11cd')

# %%
euclidean_distance_matrix
# Out:
#           euclidean     origin   dest  ...   msoa11cd  MSOA_lon   MSOA_lat
# 0      13167.873206  E02002527    124  ...  E02002527 -0.895104  54.556813
# 1      12162.918741  E02002527   4155  ...  E02002527 -0.895104  54.556813
# 2        414.405629  E02002527   4159  ...  E02002527 -0.895104  54.556813
# 3      12726.938554  E02002527   4162  ...  E02002527 -0.895104  54.556813
# 4       8900.118874  E02002527   4609  ...  E02002527 -0.895104  54.556813
# ...             ...        ...    ...  ...        ...       ...        ...
# 18989   3422.794868  E02006880  18563  ...  E02006880  1.167870  51.078965
# 18990    868.464919  E02006880  18686  ...  E02006880  1.167870  51.078965
# 18991  15418.968215  E02006880  18900  ...  E02006880  1.167870  51.078965
# 18992   3953.783726  E02006880  19549  ...  E02006880  1.167870  51.078965
# 18993   6479.347506  E02006880  19886  ...  E02006880  1.167870  51.078965
#
# [18994 rows x 9 columns]

# %%
#euclidean_distance_matrix.drop(columns=['msoa11cd','name'], axis=1,inplace=True)
#euclidean_distance_matrix

# %%
euclidean_distance_matrix.shape
# Out:
# (18994, 9)

# %%
euclidean_distance_matrix_sub01=euclidean_distance_matrix[1:18994]

# %%
euclidean_distance_matrix_sub01
# Out:
#           euclidean     origin   dest  ...   msoa11cd  MSOA_lon   MSOA_lat
# 1      12162.918741  E02002527   4155  ...  E02002527 -0.895104  54.556813
# 2        414.405629  E02002527   4159  ...  E02002527 -0.895104  54.556813
# 3      12726.938554  E02002527   4162  ...  E02002527 -0.895104  54.556813
# 4       8900.118874  E02002527   4609  ...  E02002527 -0.895104  54.556813
# 5      10475.400150  E02002527   5050  ...  E02002527 -0.895104  54.556813
# ...             ...        ...    ...  ...        ...       ...        ...
# 18989   3422.794868  E02006880  18563  ...  E02006880  1.167870  51.078965
# 18990    868.464919  E02006880  18686  ...  E02006880  1.167870  51.078965
# 18991  15418.968215  E02006880  18900  ...  E02006880  1.167870  51.078965
# 18992   3953.783726  E02006880  19549  ...  E02006880  1.167870  51.078965
# 18993   6479.347506  E02006880  19886  ...  E02006880  1.167870  51.078965
#
# [18993 rows x 9 columns]

# %%
distance_list = []
origin_id_list = []
destination_id_list = []

for (i1, row1) in euclidean_distance_matrix_sub01.iterrows():
    LatOrigin = str(row1['MSOA_lat'])
    LongOrigin = str(row1['MSOA_lon'])
    origin_id = row1['origin']
    
    LatDestination = str(row1['point_lat'])
    LongDestination = str(row1['point_lon'])
    destination_id = row1['dest']
    
    url = "http://82.11.51.26:5000/route/v1/driving/" + LongOrigin +","+ LatOrigin + ";" + LongDestination +","+ LatDestination + "?steps=false"
    result_distance = requests.get(url).json()['routes'][0]['distance']
    distance_list.append(result_distance)
    origin_id_list.append(origin_id)
    destination_id_list.append(destination_id)

output01 = pd.DataFrame(distance_list, columns = ['Distance in meter'])
output01['origin_id'] = origin_id_list
output01['destination_id'] = destination_id_list
output01
# Out:
#        Distance in meter  origin_id  destination_id
# 0                15669.6  E02002527            4155
# 1                  608.3  E02002527            4159
# 2                16577.0  E02002527            4162
# 3                11904.9  E02002527            4609
# 4                14355.9  E02002527            5050
# ...                  ...        ...             ...
# 18988             4303.6  E02006880           18563
# 18989             1405.0  E02006880           18686
# 18990            19443.3  E02006880           18900
# 18991             6235.8  E02006880           19549
# 18992             7014.5  E02006880           19886
#
# [18993 rows x 3 columns]

# %%
output01.to_csv('distance18993.csv')

# %%
files.download('distance18993.csv')
